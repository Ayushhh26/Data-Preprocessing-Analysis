# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in d:\program files\anacon\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in d:\program files\anacon\lib\site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in d:\program files\anacon\lib\site-packages (from scikit-learn->sklearn) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\program files\anacon\lib\site-packages (from scikit-learn->sklearn) (2.2.0)
# Requirement already satisfied: scipy>=1.1.0 in d:\program files\anacon\lib\site-packages (from scikit-learn->sklearn) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in d:\program files\anacon\lib\site-packages (from scikit-learn->sklearn) (1.1.0)

# %%
df = pd.read_csv("Data.csv")

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# ## 1. Removing the Rows

# %%
df.dropna()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# ## 2. Using Imputers

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.iloc[:,1:3].values
# Out:
# array([[4.4e+01, 7.2e+04],
#        [2.7e+01, 4.8e+04],
#        [3.0e+01, 5.4e+04],
#        [3.8e+01, 6.1e+04],
#        [4.0e+01,     nan],
#        [3.5e+01, 5.8e+04],
#        [    nan, 5.2e+04],
#        [4.8e+01, 7.9e+04],
#        [5.0e+01, 8.3e+04],
#        [3.7e+01, 6.7e+04]])

# %%
imputer.fit(df.iloc[:,1:3].values)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
df.iloc[:,1:3] = imputer.transform(df.iloc[:,1:3].values)

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# # Categorical

# %%
imputer.fit(df.iloc[:,:].values)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
df.iloc[:,:]=imputer.transform(df.iloc[:,:].values)

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2   France  30.0  54000.0       Yes
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes
